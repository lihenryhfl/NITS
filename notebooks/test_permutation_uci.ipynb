# %%
import argparse
import time
import torch
import numpy as np
import matplotlib.pyplot as plt
from nits.model import *
from nits.fc_model import *
from maf.datasets import *
from nits.resmade import ResidualMADE

def list_str_to_list(s):
    print(s)
    assert s[0] == '[' and s[-1] == ']'
    s = s[1:-1]
    s = s.replace(' ', '')
    s = s.split(',')

    s = [int(x) for x in s]

    return s
    
def create_batcher(x, batch_size=1):
    idx = 0
    p = torch.randperm(len(x))
    x = x[p]

    while idx + batch_size < len(x):
        yield torch.tensor(x[idx:idx+batch_size], device=device).float()
        idx += batch_size
    else:
        yield torch.tensor(x[idx:], device=device).float()
        
class Dataset:
    def __init__(self, x, permute=False, train_idx=0, val_idx=0):
        # splits x into train, val, and test
        self.n = len(x)
        if permute:
            p = np.random.permutation(self.n)
            x = x[p]
            
        train_idx = train_idx if train_idx else int(0.8 * self.n)
        val_idx = val_idx if val_idx else int(0.9 * self.n)
        
        class DataHolder:
            def __init__(self, x):
                self.x = x
                
        self.trn = DataHolder(x[:train_idx])
        self.val = DataHolder(x[train_idx:val_idx])
        self.tst = DataHolder(x[val_idx:])
        
def build_tridiagonal(n=1000000, d=30, k=1, permute=False):
    precov = np.random.normal(size=(d, d))
    precov = np.matmul(precov, precov.T)
    cov = np.tril(np.triu(precov, -k), k)
    cov = cov / np.diag(cov).mean()
    
    pre_x = np.random.normal(size=(n, d))
    x = np.matmul(pre_x, cov)
    
    # normalize
    m = np.mean(x, axis=0, keepdims=True)
    std = np.std(x, axis=0, keepdims=True)
    assert m.shape == x[0:1].shape and std.shape == x[0:1].shape
    x = (x - m) / std
    
    return Dataset(x.astype(np.float))

def permute_data(dataset):
    d = dataset.trn.x.shape[1]
    train_idx = len(dataset.trn.x)
    val_idx = train_idx + len(dataset.val.x)
    x = np.concatenate([dataset.trn.x, dataset.val.x, dataset.tst.x], axis=0)
    
    P = np.eye(d)
    P = P[np.random.permutation(d)]
    permuted_x = np.matmul(x, P)
    assert np.allclose(np.matmul(permuted_x, P.T), x)
    
    return Dataset(permuted_x.astype(np.float), train_idx=train_idx, val_idx=val_idx), P.astype(np.float)

# %%
parser = argparse.ArgumentParser()

parser.add_argument('-d', '--dataset', type=str, default='gas')
parser.add_argument('-g', '--gpu', type=str, default='')
parser.add_argument('-s', '--seed', type=int, default=1)
parser.add_argument('-b', '--batch_size', type=int, default=1024)
parser.add_argument('-hi', '--hidden_dim', type=int, default=64)
parser.add_argument('-nr', '--n_residual_blocks', type=int, default=2)
parser.add_argument('-n', '--patience', type=int, default=-1)
parser.add_argument('-ga', '--gamma', type=float, default=1)
parser.add_argument('-pd', '--polyak_decay', type=float, default=1 - 5e-5)
parser.add_argument('-a', '--nits_arch', type=list_str_to_list, default='[16,16,1]')
parser.add_argument('-r', '--rotate', action='store_true')
parser.add_argument('-dn', '--dont_normalize_inverse', type=bool, default=False)
parser.add_argument('-l', '--learning_rate', type=float, default=2e-4)
parser.add_argument('-p', '--dropout', type=float, default=-1.0)
parser.add_argument('-rc', '--add_residual_connections', type=bool, default=False)
parser.add_argument('-bm', '--bound_multiplier', type=float, default=1.0)
parser.add_argument('-pe', '--permute_data', action='store_true')

# args = parser.parse_args(['-g', '6', '-d', 'tridiagonal', '-pe', '-r',])
args = parser.parse_args(['-g', '6', '-pe', '-r', '-b', '1024', '-hi', '1024'])

np.random.seed(args.seed)
torch.manual_seed(args.seed)

device = 'cuda:' + args.gpu if args.gpu else 'cpu'

use_batch_norm = False
zero_initialization = True
weight_norm = False
default_patience = 10
if args.dataset == 'gas':
    # training set size: 852,174
    data = gas.GAS()
    default_dropout = 0.1
elif args.dataset == 'power':
    # training set size: 1,659,917
    data = power.POWER()
    default_dropout = 0.1
elif args.dataset == 'miniboone':
    # training set size: 29,556
    data = miniboone.MINIBOONE()
    default_dropout = 0.3
elif args.dataset == 'hepmass':
    # training set size: 315,123
    data = hepmass.HEPMASS()
    default_dropout = 0.5
    default_pateince = 3
elif args.dataset == 'bsds300':
    # training set size: 1,000,000
    data = bsds300.BSDS300()
    default_dropout = 0.2
elif args.dataset == 'tridiagonal':
    data = build_tridiagonal()
    default_dropout = 0.0
    
if args.permute_data:
    print("PERMUTED DATA")
    data, P = permute_data(data)
    print("P\n", np.arange(data.trn.x.shape[1]).reshape(1, -1)@(P))

args.patience = args.patience if args.patience >= 0 else default_patience
args.dropout = args.dropout if args.dropout >= 0.0 else default_dropout
print(args)

d = data.trn.x.shape[1]

max_val = max(data.trn.x.max(), data.val.x.max(), data.tst.x.max())
min_val = min(data.trn.x.min(), data.val.x.min(), data.tst.x.min())
max_val, min_val = torch.tensor(max_val).to(device).float(), torch.tensor(min_val).to(device).float()

max_val *= args.bound_multiplier
min_val *= args.bound_multiplier

nits_model = NITS(d=d, start=min_val, end=max_val, monotonic_const=1e-5,
                  A_constraint='neg_exp', arch=[1] + args.nits_arch,
                  final_layer_constraint='softmax',
                  add_residual_connections=args.add_residual_connections,
                  normalize_inverse=(not args.dont_normalize_inverse),
                  softmax_temperature=False).to(device)

model = ResMADEModel(
    d=d,
    rotate=args.rotate,
    nits_model=nits_model,
    n_residual_blocks=args.n_residual_blocks,
    hidden_dim=args.hidden_dim,
    dropout_probability=args.dropout,
    use_batch_norm=use_batch_norm,
    zero_initialization=zero_initialization,
    weight_norm=weight_norm
).to(device)

shadow = ResMADEModel(
    d=d,
    rotate=args.rotate,
    nits_model=nits_model,
    n_residual_blocks=args.n_residual_blocks,
    hidden_dim=args.hidden_dim,
    dropout_probability=args.dropout,
    use_batch_norm=use_batch_norm,
    zero_initialization=zero_initialization,
    weight_norm=weight_norm
).to(device)

# initialize weight norm
if weight_norm:
    with torch.no_grad():
        for i, x in enumerate(create_batcher(data.trn.x, batch_size=args.batch_size)):
            params = model(x)
            break

model = EMA(model, shadow, decay=args.polyak_decay).to(device)

print_every = 10
optim = torch.optim.Adam(model.parameters(), lr=args.learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optim, step_size=1, gamma=args.gamma)

time_ = time.time()
epoch = 0
train_ll = 0.
max_val_ll = -np.inf
patience = args.patience
keep_training = True
while keep_training:
    model.train()
    for i, x in enumerate(create_batcher(data.trn.x, batch_size=args.batch_size)):
        ll = model(x)
        optim.zero_grad()
        (-ll).backward()
        train_ll += ll.detach().cpu().numpy()

        optim.step()
        scheduler.step()
        model.update()

    epoch += 1

    if epoch % print_every == 0:
        # compute train loss
        train_ll /= len(data.trn.x) * print_every
        lr = optim.param_groups[0]['lr']

        with torch.no_grad():
            model.eval()
            val_ll = 0.
            ema_val_ll = 0.
            for i, x in enumerate(create_batcher(data.val.x, batch_size=args.batch_size)):
                x = torch.tensor(x, device=device)
                val_ll += model.model(x).detach().cpu().numpy()
                ema_val_ll += model(x).detach().cpu().numpy()

            val_ll /= len(data.val.x)
            ema_val_ll /= len(data.val.x)

        # early stopping
        if ema_val_ll > max_val_ll + 1e-4:
            patience = args.patience
            max_val_ll = ema_val_ll
        else:
            patience -= 1

        if patience == 0:
            print("Patience reached zero. max_val_ll stayed at {:.3f} for {:d} iterations.".format(max_val_ll, args.patience))
            keep_training = False

        with torch.no_grad():
            model.eval()
            test_ll = 0.
            ema_test_ll = 0.
            for i, x in enumerate(create_batcher(data.tst.x, batch_size=args.batch_size)):
                x = torch.tensor(x, device=device)
                test_ll += model.model(x).detach().cpu().numpy()
                ema_test_ll += model(x).detach().cpu().numpy()

            test_ll /= len(data.tst.x)
            ema_test_ll /= len(data.tst.x)

        fmt_str1 = 'epoch: {:3d}, time: {:3d}s, train_ll: {:.3f},'
        fmt_str2 = ' ema_val_ll: {:.3f}, ema_test_ll: {:.3f},'
        fmt_str3 = ' val_ll: {:.3f}, test_ll: {:.3f}, lr: {:.2e}'

        print((fmt_str1 + fmt_str2 + fmt_str3).format(
            epoch,
            int(time.time() - time_),
            train_ll,
            ema_val_ll,
            ema_test_ll,
            val_ll,
            test_ll,
            lr))

        time_ = time.time()
        train_ll = 0.

    if epoch % (print_every * 10) == 0:
        print(args)
# Out:
# [16,16,1]
# PERMUTED DATA
# P
#  [[4. 2. 1. 6. 5. 7. 3. 0.]]
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# /home/henry/projects/NITS/nits/model.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('start_val', torch.tensor(start))
# /home/henry/projects/NITS/nits/model.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('end_val', torch.tensor(end))
# /home/henry/projects/NITS/nits/model.py:359: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('start', torch.tensor(start).reshape(1, 1).tile(1, d))
# /home/henry/projects/NITS/nits/model.py:360: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('end', torch.tensor(end).reshape(1, 1).tile(1, d))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:173: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# epoch:  10, time: 149s, train_ll: 4.913, ema_val_ll: -33.917, ema_test_ll: -33.897, val_ll: 7.336, test_ll: 7.350, lr: 2.00e-04
# epoch:  20, time: 149s, train_ll: 8.398, ema_val_ll: -23.221, ema_test_ll: -23.213, val_ll: 8.909, test_ll: 8.929, lr: 2.00e-04
# epoch:  30, time: 149s, train_ll: 9.207, ema_val_ll: -14.361, ema_test_ll: -14.363, val_ll: 9.272, test_ll: 9.283, lr: 2.00e-04
# epoch:  40, time: 146s, train_ll: 8.199, ema_val_ll: -12.623, ema_test_ll: -12.661, val_ll: 9.424, test_ll: 9.437, lr: 2.00e-04
# epoch:  50, time: 143s, train_ll: 9.578, ema_val_ll: -26.166, ema_test_ll: -26.219, val_ll: 9.973, test_ll: 9.988, lr: 2.00e-04
# epoch:  60, time: 143s, train_ll: 10.084, ema_val_ll: -6.818, ema_test_ll: -6.837, val_ll: 10.446, test_ll: 10.454, lr: 2.00e-04
# epoch:  70, time: 144s, train_ll: 10.405, ema_val_ll: -2.838, ema_test_ll: -2.848, val_ll: 10.568, test_ll: 10.578, lr: 2.00e-04
# epoch:  80, time: 146s, train_ll: 10.642, ema_val_ll: 0.714, ema_test_ll: 0.715, val_ll: 10.903, test_ll: 10.923, lr: 2.00e-04
# epoch:  90, time: 147s, train_ll: 10.824, ema_val_ll: 3.970, ema_test_ll: 3.977, val_ll: 10.975, test_ll: 10.986, lr: 2.00e-04
# epoch: 100, time: 148s, train_ll: 10.975, ema_val_ll: 6.664, ema_test_ll: 6.673, val_ll: 11.137, test_ll: 11.150, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 110, time: 147s, train_ll: 11.101, ema_val_ll: 8.618, ema_test_ll: 8.627, val_ll: 11.218, test_ll: 11.228, lr: 2.00e-04
# epoch: 120, time: 147s, train_ll: 11.210, ema_val_ll: 9.874, ema_test_ll: 9.881, val_ll: 11.350, test_ll: 11.357, lr: 2.00e-04
# epoch: 130, time: 143s, train_ll: 11.307, ema_val_ll: 10.632, ema_test_ll: 10.638, val_ll: 11.231, test_ll: 11.232, lr: 2.00e-04
# epoch: 140, time: 143s, train_ll: 11.393, ema_val_ll: 11.108, ema_test_ll: 11.114, val_ll: 11.244, test_ll: 11.252, lr: 2.00e-04
# epoch: 150, time: 141s, train_ll: 11.470, ema_val_ll: 11.418, ema_test_ll: 11.423, val_ll: 11.579, test_ll: 11.587, lr: 2.00e-04
# epoch: 160, time: 140s, train_ll: 11.541, ema_val_ll: 11.630, ema_test_ll: 11.634, val_ll: 11.767, test_ll: 11.770, lr: 2.00e-04
# epoch: 170, time: 142s, train_ll: 11.605, ema_val_ll: 11.766, ema_test_ll: 11.770, val_ll: 11.783, test_ll: 11.789, lr: 2.00e-04
# epoch: 180, time: 142s, train_ll: 11.662, ema_val_ll: 11.869, ema_test_ll: 11.873, val_ll: 11.802, test_ll: 11.811, lr: 2.00e-04
# epoch: 190, time: 139s, train_ll: 11.715, ema_val_ll: 11.949, ema_test_ll: 11.953, val_ll: 11.836, test_ll: 11.843, lr: 2.00e-04
# epoch: 200, time: 140s, train_ll: 11.764, ema_val_ll: 12.014, ema_test_ll: 12.017, val_ll: 11.761, test_ll: 11.767, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 210, time: 142s, train_ll: 11.809, ema_val_ll: 12.079, ema_test_ll: 12.081, val_ll: 11.898, test_ll: 11.901, lr: 2.00e-04
# epoch: 220, time: 143s, train_ll: 11.850, ema_val_ll: 12.138, ema_test_ll: 12.140, val_ll: 12.028, test_ll: 12.028, lr: 2.00e-04
# epoch: 230, time: 147s, train_ll: 11.891, ema_val_ll: 12.192, ema_test_ll: 12.194, val_ll: 11.921, test_ll: 11.930, lr: 2.00e-04
# epoch: 240, time: 144s, train_ll: 11.927, ema_val_ll: 12.240, ema_test_ll: 12.242, val_ll: 12.084, test_ll: 12.088, lr: 2.00e-04
# epoch: 250, time: 146s, train_ll: 11.961, ema_val_ll: 12.280, ema_test_ll: 12.282, val_ll: 12.032, test_ll: 12.041, lr: 2.00e-04
# epoch: 260, time: 147s, train_ll: 11.993, ema_val_ll: 12.316, ema_test_ll: 12.317, val_ll: 12.067, test_ll: 12.068, lr: 2.00e-04
# epoch: 270, time: 148s, train_ll: 12.024, ema_val_ll: 12.347, ema_test_ll: 12.349, val_ll: 12.087, test_ll: 12.093, lr: 2.00e-04
# epoch: 280, time: 146s, train_ll: 12.052, ema_val_ll: 12.368, ema_test_ll: 12.369, val_ll: 12.060, test_ll: 12.065, lr: 2.00e-04
# epoch: 290, time: 146s, train_ll: 12.079, ema_val_ll: 12.392, ema_test_ll: 12.394, val_ll: 12.172, test_ll: 12.172, lr: 2.00e-04
# epoch: 300, time: 148s, train_ll: 12.105, ema_val_ll: 12.426, ema_test_ll: 12.428, val_ll: 12.237, test_ll: 12.243, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 310, time: 140s, train_ll: 12.129, ema_val_ll: 12.457, ema_test_ll: 12.459, val_ll: 12.178, test_ll: 12.186, lr: 2.00e-04
# epoch: 320, time: 138s, train_ll: 12.153, ema_val_ll: 12.480, ema_test_ll: 12.482, val_ll: 12.267, test_ll: 12.264, lr: 2.00e-04
# epoch: 330, time: 139s, train_ll: 12.175, ema_val_ll: 12.503, ema_test_ll: 12.505, val_ll: 12.170, test_ll: 12.177, lr: 2.00e-04
# epoch: 340, time: 141s, train_ll: 12.197, ema_val_ll: 12.525, ema_test_ll: 12.527, val_ll: 12.236, test_ll: 12.243, lr: 2.00e-04
# epoch: 350, time: 140s, train_ll: 12.217, ema_val_ll: 12.546, ema_test_ll: 12.547, val_ll: 12.276, test_ll: 12.280, lr: 2.00e-04
# epoch: 360, time: 140s, train_ll: 12.237, ema_val_ll: 12.565, ema_test_ll: 12.566, val_ll: 12.331, test_ll: 12.332, lr: 2.00e-04
# epoch: 370, time: 137s, train_ll: 12.256, ema_val_ll: 12.582, ema_test_ll: 12.583, val_ll: 12.288, test_ll: 12.293, lr: 2.00e-04
# epoch: 380, time: 140s, train_ll: 12.275, ema_val_ll: 12.598, ema_test_ll: 12.598, val_ll: 12.171, test_ll: 12.176, lr: 2.00e-04
# epoch: 390, time: 142s, train_ll: 12.292, ema_val_ll: 12.610, ema_test_ll: 12.611, val_ll: 12.247, test_ll: 12.249, lr: 2.00e-04
# epoch: 400, time: 137s, train_ll: 12.310, ema_val_ll: 12.621, ema_test_ll: 12.622, val_ll: 12.378, test_ll: 12.382, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 410, time: 142s, train_ll: 12.327, ema_val_ll: 12.634, ema_test_ll: 12.634, val_ll: 12.410, test_ll: 12.409, lr: 2.00e-04
# epoch: 420, time: 144s, train_ll: 12.343, ema_val_ll: 12.647, ema_test_ll: 12.648, val_ll: 12.396, test_ll: 12.398, lr: 2.00e-04
# epoch: 430, time: 139s, train_ll: 12.357, ema_val_ll: 12.659, ema_test_ll: 12.660, val_ll: 12.370, test_ll: 12.379, lr: 2.00e-04
# epoch: 440, time: 138s, train_ll: 12.372, ema_val_ll: 12.671, ema_test_ll: 12.672, val_ll: 12.412, test_ll: 12.414, lr: 2.00e-04
# epoch: 450, time: 138s, train_ll: 12.387, ema_val_ll: 12.685, ema_test_ll: 12.685, val_ll: 12.424, test_ll: 12.426, lr: 2.00e-04
# epoch: 460, time: 141s, train_ll: 12.400, ema_val_ll: 12.694, ema_test_ll: 12.695, val_ll: 12.412, test_ll: 12.416, lr: 2.00e-04
# epoch: 470, time: 139s, train_ll: 12.413, ema_val_ll: 12.702, ema_test_ll: 12.703, val_ll: 12.491, test_ll: 12.492, lr: 2.00e-04
# epoch: 480, time: 140s, train_ll: 12.426, ema_val_ll: 12.711, ema_test_ll: 12.712, val_ll: 12.418, test_ll: 12.417, lr: 2.00e-04
# epoch: 490, time: 140s, train_ll: 12.440, ema_val_ll: 12.723, ema_test_ll: 12.725, val_ll: 12.468, test_ll: 12.472, lr: 2.00e-04
# epoch: 500, time: 137s, train_ll: 12.451, ema_val_ll: 12.733, ema_test_ll: 12.735, val_ll: 12.472, test_ll: 12.475, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 510, time: 139s, train_ll: 12.461, ema_val_ll: 12.743, ema_test_ll: 12.745, val_ll: 12.471, test_ll: 12.474, lr: 2.00e-04
# epoch: 520, time: 138s, train_ll: 12.474, ema_val_ll: 12.752, ema_test_ll: 12.754, val_ll: 12.473, test_ll: 12.480, lr: 2.00e-04
# epoch: 530, time: 141s, train_ll: 12.486, ema_val_ll: 12.757, ema_test_ll: 12.760, val_ll: 12.513, test_ll: 12.519, lr: 2.00e-04
# epoch: 540, time: 140s, train_ll: 12.496, ema_val_ll: 12.764, ema_test_ll: 12.768, val_ll: 12.478, test_ll: 12.476, lr: 2.00e-04
# epoch: 550, time: 136s, train_ll: 12.507, ema_val_ll: 12.770, ema_test_ll: 12.773, val_ll: 12.460, test_ll: 12.462, lr: 2.00e-04
# epoch: 560, time: 138s, train_ll: 12.516, ema_val_ll: 12.776, ema_test_ll: 12.781, val_ll: 12.475, test_ll: 12.484, lr: 2.00e-04
# epoch: 570, time: 138s, train_ll: 12.526, ema_val_ll: 12.781, ema_test_ll: 12.786, val_ll: 12.369, test_ll: 12.376, lr: 2.00e-04
# epoch: 580, time: 140s, train_ll: 12.536, ema_val_ll: 12.785, ema_test_ll: 12.790, val_ll: 12.568, test_ll: 12.581, lr: 2.00e-04
# epoch: 590, time: 142s, train_ll: 12.545, ema_val_ll: 12.788, ema_test_ll: 12.793, val_ll: 12.547, test_ll: 12.550, lr: 2.00e-04
# epoch: 600, time: 142s, train_ll: 12.555, ema_val_ll: 12.796, ema_test_ll: 12.801, val_ll: 12.492, test_ll: 12.501, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 610, time: 137s, train_ll: 12.564, ema_val_ll: 12.800, ema_test_ll: 12.805, val_ll: 12.579, test_ll: 12.581, lr: 2.00e-04
# epoch: 620, time: 144s, train_ll: 12.573, ema_val_ll: 12.805, ema_test_ll: 12.810, val_ll: 12.575, test_ll: 12.579, lr: 2.00e-04
# epoch: 630, time: 151s, train_ll: 12.581, ema_val_ll: 12.808, ema_test_ll: 12.814, val_ll: 12.582, test_ll: 12.588, lr: 2.00e-04
# epoch: 640, time: 150s, train_ll: 12.589, ema_val_ll: 12.813, ema_test_ll: 12.819, val_ll: 12.577, test_ll: 12.582, lr: 2.00e-04
# epoch: 650, time: 150s, train_ll: 12.597, ema_val_ll: 12.817, ema_test_ll: 12.823, val_ll: 12.575, test_ll: 12.588, lr: 2.00e-04
# epoch: 660, time: 150s, train_ll: 12.604, ema_val_ll: 12.823, ema_test_ll: 12.830, val_ll: 12.618, test_ll: 12.622, lr: 2.00e-04
# epoch: 670, time: 150s, train_ll: 12.612, ema_val_ll: 12.830, ema_test_ll: 12.836, val_ll: 12.637, test_ll: 12.640, lr: 2.00e-04
# epoch: 680, time: 149s, train_ll: 12.620, ema_val_ll: 12.837, ema_test_ll: 12.843, val_ll: 12.604, test_ll: 12.613, lr: 2.00e-04
# epoch: 690, time: 150s, train_ll: 12.628, ema_val_ll: 12.842, ema_test_ll: 12.848, val_ll: 12.618, test_ll: 12.618, lr: 2.00e-04
# epoch: 700, time: 151s, train_ll: 12.636, ema_val_ll: 12.845, ema_test_ll: 12.852, val_ll: 12.549, test_ll: 12.549, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 710, time: 145s, train_ll: 12.643, ema_val_ll: 12.850, ema_test_ll: 12.857, val_ll: 12.600, test_ll: 12.611, lr: 2.00e-04
# epoch: 720, time: 146s, train_ll: 12.650, ema_val_ll: 12.858, ema_test_ll: 12.864, val_ll: 12.609, test_ll: 12.619, lr: 2.00e-04
# epoch: 730, time: 148s, train_ll: 12.656, ema_val_ll: 12.863, ema_test_ll: 12.870, val_ll: 12.545, test_ll: 12.551, lr: 2.00e-04
# epoch: 740, time: 131s, train_ll: 12.663, ema_val_ll: 12.869, ema_test_ll: 12.876, val_ll: 12.618, test_ll: 12.629, lr: 2.00e-04
# epoch: 750, time: 129s, train_ll: 12.670, ema_val_ll: 12.870, ema_test_ll: 12.878, val_ll: 12.672, test_ll: 12.677, lr: 2.00e-04
# epoch: 760, time: 130s, train_ll: 12.676, ema_val_ll: 12.875, ema_test_ll: 12.883, val_ll: 12.567, test_ll: 12.585, lr: 2.00e-04
# epoch: 770, time: 130s, train_ll: 12.683, ema_val_ll: 12.877, ema_test_ll: 12.885, val_ll: 12.595, test_ll: 12.602, lr: 2.00e-04
# epoch: 780, time: 130s, train_ll: 12.689, ema_val_ll: 12.882, ema_test_ll: 12.890, val_ll: 12.650, test_ll: 12.656, lr: 2.00e-04
# epoch: 790, time: 130s, train_ll: 12.696, ema_val_ll: 12.883, ema_test_ll: 12.891, val_ll: 12.629, test_ll: 12.636, lr: 2.00e-04
# epoch: 800, time: 130s, train_ll: 12.702, ema_val_ll: 12.884, ema_test_ll: 12.893, val_ll: 12.664, test_ll: 12.672, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 810, time: 129s, train_ll: 12.708, ema_val_ll: 12.887, ema_test_ll: 12.895, val_ll: 12.710, test_ll: 12.716, lr: 2.00e-04
# epoch: 820, time: 130s, train_ll: 12.713, ema_val_ll: 12.888, ema_test_ll: 12.896, val_ll: 12.682, test_ll: 12.689, lr: 2.00e-04
# epoch: 830, time: 130s, train_ll: 12.719, ema_val_ll: 12.891, ema_test_ll: 12.899, val_ll: 12.658, test_ll: 12.669, lr: 2.00e-04
# epoch: 840, time: 130s, train_ll: 12.724, ema_val_ll: 12.892, ema_test_ll: 12.901, val_ll: 12.652, test_ll: 12.655, lr: 2.00e-04
# epoch: 850, time: 130s, train_ll: 12.730, ema_val_ll: 12.891, ema_test_ll: 12.900, val_ll: 12.539, test_ll: 12.548, lr: 2.00e-04
# epoch: 860, time: 130s, train_ll: 12.736, ema_val_ll: 12.889, ema_test_ll: 12.898, val_ll: 12.728, test_ll: 12.730, lr: 2.00e-04
# epoch: 870, time: 130s, train_ll: 12.740, ema_val_ll: 12.889, ema_test_ll: 12.899, val_ll: 12.692, test_ll: 12.700, lr: 2.00e-04
# epoch: 880, time: 130s, train_ll: 12.745, ema_val_ll: 12.895, ema_test_ll: 12.905, val_ll: 12.711, test_ll: 12.717, lr: 2.00e-04
# epoch: 890, time: 130s, train_ll: 12.751, ema_val_ll: 12.898, ema_test_ll: 12.908, val_ll: 12.575, test_ll: 12.585, lr: 2.00e-04
# epoch: 900, time: 130s, train_ll: 12.756, ema_val_ll: 12.898, ema_test_ll: 12.908, val_ll: 12.702, test_ll: 12.713, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 910, time: 129s, train_ll: 12.761, ema_val_ll: 12.903, ema_test_ll: 12.913, val_ll: 12.632, test_ll: 12.636, lr: 2.00e-04
# epoch: 920, time: 130s, train_ll: 12.767, ema_val_ll: 12.904, ema_test_ll: 12.915, val_ll: 12.729, test_ll: 12.737, lr: 2.00e-04
# epoch: 930, time: 130s, train_ll: 12.771, ema_val_ll: 12.903, ema_test_ll: 12.913, val_ll: 12.715, test_ll: 12.717, lr: 2.00e-04
# epoch: 940, time: 130s, train_ll: 12.776, ema_val_ll: 12.905, ema_test_ll: 12.915, val_ll: 12.712, test_ll: 12.723, lr: 2.00e-04
# epoch: 950, time: 130s, train_ll: 12.781, ema_val_ll: 12.906, ema_test_ll: 12.917, val_ll: 12.715, test_ll: 12.724, lr: 2.00e-04
# epoch: 960, time: 130s, train_ll: 12.785, ema_val_ll: 12.905, ema_test_ll: 12.915, val_ll: 12.678, test_ll: 12.690, lr: 2.00e-04
# epoch: 970, time: 130s, train_ll: 12.790, ema_val_ll: 12.909, ema_test_ll: 12.920, val_ll: 12.694, test_ll: 12.706, lr: 2.00e-04
# epoch: 980, time: 130s, train_ll: 12.794, ema_val_ll: 12.909, ema_test_ll: 12.920, val_ll: 12.729, test_ll: 12.736, lr: 2.00e-04
# epoch: 990, time: 130s, train_ll: 12.798, ema_val_ll: 12.910, ema_test_ll: 12.921, val_ll: 12.684, test_ll: 12.692, lr: 2.00e-04
# epoch: 1000, time: 130s, train_ll: 12.803, ema_val_ll: 12.918, ema_test_ll: 12.929, val_ll: 12.625, test_ll: 12.633, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1010, time: 130s, train_ll: 12.807, ema_val_ll: 12.928, ema_test_ll: 12.939, val_ll: 12.687, test_ll: 12.698, lr: 2.00e-04
# epoch: 1020, time: 129s, train_ll: 12.812, ema_val_ll: 12.929, ema_test_ll: 12.939, val_ll: 12.711, test_ll: 12.717, lr: 2.00e-04
# epoch: 1030, time: 130s, train_ll: 12.816, ema_val_ll: 12.927, ema_test_ll: 12.938, val_ll: 12.707, test_ll: 12.718, lr: 2.00e-04
# epoch: 1040, time: 129s, train_ll: 12.820, ema_val_ll: 12.928, ema_test_ll: 12.938, val_ll: 12.771, test_ll: 12.786, lr: 2.00e-04
# epoch: 1050, time: 129s, train_ll: 12.824, ema_val_ll: 12.927, ema_test_ll: 12.938, val_ll: 12.732, test_ll: 12.742, lr: 2.00e-04
# epoch: 1060, time: 130s, train_ll: 12.828, ema_val_ll: 12.927, ema_test_ll: 12.938, val_ll: 12.745, test_ll: 12.752, lr: 2.00e-04
# epoch: 1070, time: 129s, train_ll: 12.833, ema_val_ll: 12.931, ema_test_ll: 12.941, val_ll: 12.731, test_ll: 12.745, lr: 2.00e-04
# epoch: 1080, time: 129s, train_ll: 12.836, ema_val_ll: 12.932, ema_test_ll: 12.942, val_ll: 12.718, test_ll: 12.728, lr: 2.00e-04
# epoch: 1090, time: 130s, train_ll: 12.840, ema_val_ll: 12.934, ema_test_ll: 12.944, val_ll: 12.729, test_ll: 12.736, lr: 2.00e-04
# epoch: 1100, time: 129s, train_ll: 12.844, ema_val_ll: 12.935, ema_test_ll: 12.945, val_ll: 12.699, test_ll: 12.707, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1110, time: 129s, train_ll: 12.848, ema_val_ll: 12.939, ema_test_ll: 12.949, val_ll: 12.745, test_ll: 12.753, lr: 2.00e-04
# epoch: 1120, time: 129s, train_ll: 12.852, ema_val_ll: 12.939, ema_test_ll: 12.949, val_ll: 12.757, test_ll: 12.764, lr: 2.00e-04
# epoch: 1130, time: 129s, train_ll: 12.855, ema_val_ll: 12.937, ema_test_ll: 12.947, val_ll: 12.739, test_ll: 12.746, lr: 2.00e-04
# epoch: 1140, time: 129s, train_ll: 12.859, ema_val_ll: 12.944, ema_test_ll: 12.954, val_ll: 12.708, test_ll: 12.718, lr: 2.00e-04
# epoch: 1150, time: 129s, train_ll: 12.862, ema_val_ll: 12.941, ema_test_ll: 12.952, val_ll: 12.722, test_ll: 12.730, lr: 2.00e-04
# epoch: 1160, time: 129s, train_ll: 12.866, ema_val_ll: 12.943, ema_test_ll: 12.954, val_ll: 12.752, test_ll: 12.760, lr: 2.00e-04
# epoch: 1170, time: 129s, train_ll: 12.868, ema_val_ll: 12.943, ema_test_ll: 12.954, val_ll: 12.795, test_ll: 12.802, lr: 2.00e-04
# epoch: 1180, time: 129s, train_ll: 12.872, ema_val_ll: 12.947, ema_test_ll: 12.958, val_ll: 12.761, test_ll: 12.770, lr: 2.00e-04
# epoch: 1190, time: 130s, train_ll: 12.877, ema_val_ll: 12.949, ema_test_ll: 12.960, val_ll: 12.728, test_ll: 12.739, lr: 2.00e-04
# epoch: 1200, time: 129s, train_ll: 12.879, ema_val_ll: 12.948, ema_test_ll: 12.959, val_ll: 12.783, test_ll: 12.796, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1210, time: 130s, train_ll: 12.883, ema_val_ll: 12.951, ema_test_ll: 12.961, val_ll: 12.789, test_ll: 12.801, lr: 2.00e-04
# epoch: 1220, time: 129s, train_ll: 12.886, ema_val_ll: 12.959, ema_test_ll: 12.970, val_ll: 12.761, test_ll: 12.769, lr: 2.00e-04
# epoch: 1230, time: 129s, train_ll: 12.889, ema_val_ll: 12.960, ema_test_ll: 12.970, val_ll: 12.796, test_ll: 12.806, lr: 2.00e-04
# epoch: 1240, time: 129s, train_ll: 12.893, ema_val_ll: 12.964, ema_test_ll: 12.975, val_ll: 12.757, test_ll: 12.760, lr: 2.00e-04
# epoch: 1250, time: 129s, train_ll: 12.897, ema_val_ll: 12.969, ema_test_ll: 12.980, val_ll: 12.760, test_ll: 12.771, lr: 2.00e-04
# epoch: 1260, time: 129s, train_ll: 12.899, ema_val_ll: 12.969, ema_test_ll: 12.979, val_ll: 12.776, test_ll: 12.786, lr: 2.00e-04
# epoch: 1270, time: 129s, train_ll: 12.903, ema_val_ll: 12.972, ema_test_ll: 12.982, val_ll: 12.470, test_ll: 12.481, lr: 2.00e-04
# epoch: 1280, time: 130s, train_ll: 12.905, ema_val_ll: 12.974, ema_test_ll: 12.985, val_ll: 12.756, test_ll: 12.766, lr: 2.00e-04
# epoch: 1290, time: 129s, train_ll: 12.909, ema_val_ll: 12.974, ema_test_ll: 12.985, val_ll: 12.663, test_ll: 12.674, lr: 2.00e-04
# epoch: 1300, time: 129s, train_ll: 12.912, ema_val_ll: 12.978, ema_test_ll: 12.989, val_ll: 12.783, test_ll: 12.786, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1310, time: 129s, train_ll: 12.915, ema_val_ll: 12.980, ema_test_ll: 12.990, val_ll: 12.783, test_ll: 12.794, lr: 2.00e-04
# epoch: 1320, time: 129s, train_ll: 12.918, ema_val_ll: 12.982, ema_test_ll: 12.993, val_ll: 12.695, test_ll: 12.703, lr: 2.00e-04
# epoch: 1330, time: 129s, train_ll: 12.920, ema_val_ll: 12.985, ema_test_ll: 12.995, val_ll: 12.795, test_ll: 12.800, lr: 2.00e-04
# epoch: 1340, time: 130s, train_ll: 12.923, ema_val_ll: 12.987, ema_test_ll: 12.997, val_ll: 12.799, test_ll: 12.809, lr: 2.00e-04
# epoch: 1350, time: 129s, train_ll: 12.926, ema_val_ll: 12.989, ema_test_ll: 12.999, val_ll: 12.757, test_ll: 12.770, lr: 2.00e-04
# epoch: 1360, time: 129s, train_ll: 12.929, ema_val_ll: 12.990, ema_test_ll: 13.000, val_ll: 12.616, test_ll: 12.621, lr: 2.00e-04
# epoch: 1370, time: 129s, train_ll: 12.931, ema_val_ll: 12.992, ema_test_ll: 13.002, val_ll: 12.739, test_ll: 12.747, lr: 2.00e-04
# epoch: 1380, time: 129s, train_ll: 12.935, ema_val_ll: 12.993, ema_test_ll: 13.003, val_ll: 12.811, test_ll: 12.814, lr: 2.00e-04
# epoch: 1390, time: 129s, train_ll: 12.937, ema_val_ll: 12.995, ema_test_ll: 13.006, val_ll: 12.643, test_ll: 12.652, lr: 2.00e-04
# epoch: 1400, time: 129s, train_ll: 12.939, ema_val_ll: 12.997, ema_test_ll: 13.007, val_ll: 12.759, test_ll: 12.767, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1410, time: 130s, train_ll: 12.943, ema_val_ll: 12.997, ema_test_ll: 13.008, val_ll: 12.786, test_ll: 12.794, lr: 2.00e-04
# epoch: 1420, time: 130s, train_ll: 12.946, ema_val_ll: 12.998, ema_test_ll: 13.009, val_ll: 12.744, test_ll: 12.759, lr: 2.00e-04
# epoch: 1430, time: 129s, train_ll: 12.948, ema_val_ll: 13.000, ema_test_ll: 13.010, val_ll: 12.746, test_ll: 12.752, lr: 2.00e-04
# epoch: 1440, time: 129s, train_ll: 12.951, ema_val_ll: 13.001, ema_test_ll: 13.011, val_ll: 12.809, test_ll: 12.823, lr: 2.00e-04
# epoch: 1450, time: 129s, train_ll: 12.953, ema_val_ll: 13.002, ema_test_ll: 13.013, val_ll: 12.812, test_ll: 12.824, lr: 2.00e-04
# epoch: 1460, time: 129s, train_ll: 12.956, ema_val_ll: 13.003, ema_test_ll: 13.013, val_ll: 12.713, test_ll: 12.721, lr: 2.00e-04
# epoch: 1470, time: 129s, train_ll: 12.959, ema_val_ll: 13.004, ema_test_ll: 13.014, val_ll: 12.814, test_ll: 12.822, lr: 2.00e-04
# epoch: 1480, time: 129s, train_ll: 12.962, ema_val_ll: 13.006, ema_test_ll: 13.015, val_ll: 12.800, test_ll: 12.807, lr: 2.00e-04
# epoch: 1490, time: 129s, train_ll: 12.964, ema_val_ll: 13.007, ema_test_ll: 13.016, val_ll: 12.810, test_ll: 12.818, lr: 2.00e-04
# epoch: 1500, time: 129s, train_ll: 12.966, ema_val_ll: 13.007, ema_test_ll: 13.017, val_ll: 12.746, test_ll: 12.753, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1510, time: 129s, train_ll: 12.969, ema_val_ll: 13.007, ema_test_ll: 13.017, val_ll: 12.798, test_ll: 12.801, lr: 2.00e-04
# epoch: 1520, time: 129s, train_ll: 12.971, ema_val_ll: 13.007, ema_test_ll: 13.016, val_ll: 12.809, test_ll: 12.822, lr: 2.00e-04
# epoch: 1530, time: 129s, train_ll: 12.973, ema_val_ll: 13.009, ema_test_ll: 13.018, val_ll: 12.785, test_ll: 12.787, lr: 2.00e-04
# epoch: 1540, time: 129s, train_ll: 12.976, ema_val_ll: 13.010, ema_test_ll: 13.019, val_ll: 12.753, test_ll: 12.769, lr: 2.00e-04
# epoch: 1550, time: 129s, train_ll: 12.978, ema_val_ll: 13.010, ema_test_ll: 13.019, val_ll: 12.797, test_ll: 12.805, lr: 2.00e-04
# epoch: 1560, time: 129s, train_ll: 12.980, ema_val_ll: 13.011, ema_test_ll: 13.020, val_ll: 12.793, test_ll: 12.804, lr: 2.00e-04
# epoch: 1570, time: 129s, train_ll: 12.983, ema_val_ll: 13.012, ema_test_ll: 13.022, val_ll: 12.816, test_ll: 12.829, lr: 2.00e-04
# epoch: 1580, time: 129s, train_ll: 12.986, ema_val_ll: 13.013, ema_test_ll: 13.022, val_ll: 12.816, test_ll: 12.823, lr: 2.00e-04
# epoch: 1590, time: 129s, train_ll: 12.987, ema_val_ll: 13.014, ema_test_ll: 13.023, val_ll: 12.831, test_ll: 12.837, lr: 2.00e-04
# epoch: 1600, time: 129s, train_ll: 12.990, ema_val_ll: 13.013, ema_test_ll: 13.022, val_ll: 12.840, test_ll: 12.845, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1610, time: 129s, train_ll: 12.993, ema_val_ll: 13.013, ema_test_ll: 13.022, val_ll: 12.735, test_ll: 12.742, lr: 2.00e-04
# epoch: 1620, time: 129s, train_ll: 12.994, ema_val_ll: 13.014, ema_test_ll: 13.024, val_ll: 12.830, test_ll: 12.841, lr: 2.00e-04
# epoch: 1630, time: 129s, train_ll: 12.996, ema_val_ll: 13.016, ema_test_ll: 13.025, val_ll: 12.777, test_ll: 12.789, lr: 2.00e-04
# epoch: 1640, time: 129s, train_ll: 12.998, ema_val_ll: 13.016, ema_test_ll: 13.026, val_ll: 12.849, test_ll: 12.858, lr: 2.00e-04
# epoch: 1650, time: 129s, train_ll: 13.000, ema_val_ll: 13.017, ema_test_ll: 13.026, val_ll: 12.758, test_ll: 12.767, lr: 2.00e-04
# epoch: 1660, time: 129s, train_ll: 13.002, ema_val_ll: 13.017, ema_test_ll: 13.026, val_ll: 12.825, test_ll: 12.834, lr: 2.00e-04
# epoch: 1670, time: 129s, train_ll: 13.005, ema_val_ll: 13.016, ema_test_ll: 13.025, val_ll: 12.806, test_ll: 12.806, lr: 2.00e-04
# epoch: 1680, time: 130s, train_ll: 13.008, ema_val_ll: 13.018, ema_test_ll: 13.026, val_ll: 12.822, test_ll: 12.822, lr: 2.00e-04
# epoch: 1690, time: 130s, train_ll: 13.010, ema_val_ll: 13.019, ema_test_ll: 13.028, val_ll: 12.840, test_ll: 12.843, lr: 2.00e-04
# epoch: 1700, time: 130s, train_ll: 13.011, ema_val_ll: 13.019, ema_test_ll: 13.028, val_ll: 12.816, test_ll: 12.825, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1710, time: 129s, train_ll: 13.013, ema_val_ll: 13.019, ema_test_ll: 13.027, val_ll: 12.792, test_ll: 12.795, lr: 2.00e-04
# epoch: 1720, time: 129s, train_ll: 13.015, ema_val_ll: 13.019, ema_test_ll: 13.028, val_ll: 12.839, test_ll: 12.846, lr: 2.00e-04
# epoch: 1730, time: 129s, train_ll: 13.018, ema_val_ll: 13.020, ema_test_ll: 13.028, val_ll: 12.799, test_ll: 12.805, lr: 2.00e-04
# epoch: 1740, time: 130s, train_ll: 13.019, ema_val_ll: 13.020, ema_test_ll: 13.028, val_ll: 12.841, test_ll: 12.845, lr: 2.00e-04
# epoch: 1750, time: 129s, train_ll: 13.022, ema_val_ll: 13.021, ema_test_ll: 13.030, val_ll: 12.787, test_ll: 12.796, lr: 2.00e-04
# epoch: 1760, time: 130s, train_ll: 13.023, ema_val_ll: 13.023, ema_test_ll: 13.031, val_ll: 12.847, test_ll: 12.859, lr: 2.00e-04
# epoch: 1770, time: 130s, train_ll: 13.026, ema_val_ll: 13.022, ema_test_ll: 13.030, val_ll: 12.811, test_ll: 12.825, lr: 2.00e-04
# epoch: 1780, time: 129s, train_ll: 13.027, ema_val_ll: 13.022, ema_test_ll: 13.031, val_ll: 12.819, test_ll: 12.823, lr: 2.00e-04
# epoch: 1790, time: 129s, train_ll: 13.030, ema_val_ll: 13.024, ema_test_ll: 13.032, val_ll: 12.843, test_ll: 12.844, lr: 2.00e-04
# epoch: 1800, time: 129s, train_ll: 13.033, ema_val_ll: 13.023, ema_test_ll: 13.032, val_ll: 12.685, test_ll: 12.690, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1810, time: 129s, train_ll: 13.034, ema_val_ll: 13.023, ema_test_ll: 13.031, val_ll: 12.825, test_ll: 12.839, lr: 2.00e-04
# epoch: 1820, time: 130s, train_ll: 13.036, ema_val_ll: 13.022, ema_test_ll: 13.030, val_ll: 12.785, test_ll: 12.792, lr: 2.00e-04
# epoch: 1830, time: 129s, train_ll: 13.037, ema_val_ll: 13.023, ema_test_ll: 13.031, val_ll: 12.836, test_ll: 12.844, lr: 2.00e-04
# epoch: 1840, time: 129s, train_ll: 13.039, ema_val_ll: 13.024, ema_test_ll: 13.032, val_ll: 12.832, test_ll: 12.847, lr: 2.00e-04
# epoch: 1850, time: 129s, train_ll: 13.041, ema_val_ll: 13.024, ema_test_ll: 13.032, val_ll: 12.838, test_ll: 12.848, lr: 2.00e-04
# epoch: 1860, time: 129s, train_ll: 13.044, ema_val_ll: 13.024, ema_test_ll: 13.033, val_ll: 12.814, test_ll: 12.818, lr: 2.00e-04
# epoch: 1870, time: 128s, train_ll: 13.045, ema_val_ll: 13.024, ema_test_ll: 13.032, val_ll: 12.870, test_ll: 12.878, lr: 2.00e-04
# epoch: 1880, time: 129s, train_ll: 13.047, ema_val_ll: 13.026, ema_test_ll: 13.034, val_ll: 12.804, test_ll: 12.815, lr: 2.00e-04
# epoch: 1890, time: 129s, train_ll: 13.049, ema_val_ll: 13.026, ema_test_ll: 13.035, val_ll: 12.845, test_ll: 12.853, lr: 2.00e-04
# epoch: 1900, time: 129s, train_ll: 13.051, ema_val_ll: 13.027, ema_test_ll: 13.036, val_ll: 12.796, test_ll: 12.805, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 1910, time: 130s, train_ll: 13.053, ema_val_ll: 13.027, ema_test_ll: 13.035, val_ll: 12.834, test_ll: 12.841, lr: 2.00e-04
# epoch: 1920, time: 130s, train_ll: 13.055, ema_val_ll: 13.029, ema_test_ll: 13.037, val_ll: 12.802, test_ll: 12.811, lr: 2.00e-04
# epoch: 1930, time: 129s, train_ll: 13.056, ema_val_ll: 13.029, ema_test_ll: 13.037, val_ll: 12.835, test_ll: 12.847, lr: 2.00e-04
# epoch: 1940, time: 129s, train_ll: 13.057, ema_val_ll: 13.029, ema_test_ll: 13.037, val_ll: 12.853, test_ll: 12.862, lr: 2.00e-04
# epoch: 1950, time: 129s, train_ll: 13.059, ema_val_ll: 13.029, ema_test_ll: 13.037, val_ll: 12.838, test_ll: 12.843, lr: 2.00e-04
# epoch: 1960, time: 129s, train_ll: 13.062, ema_val_ll: 13.030, ema_test_ll: 13.038, val_ll: 12.822, test_ll: 12.827, lr: 2.00e-04
# epoch: 1970, time: 129s, train_ll: 13.063, ema_val_ll: 13.030, ema_test_ll: 13.037, val_ll: 12.845, test_ll: 12.850, lr: 2.00e-04
# epoch: 1980, time: 129s, train_ll: 13.065, ema_val_ll: 13.031, ema_test_ll: 13.039, val_ll: 12.850, test_ll: 12.863, lr: 2.00e-04
# epoch: 1990, time: 129s, train_ll: 13.067, ema_val_ll: 13.031, ema_test_ll: 13.039, val_ll: 12.816, test_ll: 12.824, lr: 2.00e-04
# epoch: 2000, time: 129s, train_ll: 13.068, ema_val_ll: 13.031, ema_test_ll: 13.039, val_ll: 12.827, test_ll: 12.828, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2010, time: 130s, train_ll: 13.070, ema_val_ll: 13.031, ema_test_ll: 13.039, val_ll: 12.819, test_ll: 12.825, lr: 2.00e-04
# epoch: 2020, time: 129s, train_ll: 13.072, ema_val_ll: 13.031, ema_test_ll: 13.038, val_ll: 12.832, test_ll: 12.843, lr: 2.00e-04
# epoch: 2030, time: 129s, train_ll: 13.073, ema_val_ll: 13.031, ema_test_ll: 13.039, val_ll: 12.784, test_ll: 12.797, lr: 2.00e-04
# epoch: 2040, time: 129s, train_ll: 13.075, ema_val_ll: 13.032, ema_test_ll: 13.040, val_ll: 12.841, test_ll: 12.851, lr: 2.00e-04
# epoch: 2050, time: 129s, train_ll: 13.076, ema_val_ll: 13.032, ema_test_ll: 13.040, val_ll: 12.848, test_ll: 12.856, lr: 2.00e-04
# epoch: 2060, time: 129s, train_ll: 13.078, ema_val_ll: 13.034, ema_test_ll: 13.042, val_ll: 12.821, test_ll: 12.828, lr: 2.00e-04
# epoch: 2070, time: 129s, train_ll: 13.080, ema_val_ll: 13.034, ema_test_ll: 13.040, val_ll: 12.844, test_ll: 12.850, lr: 2.00e-04
# epoch: 2080, time: 129s, train_ll: 13.081, ema_val_ll: 13.032, ema_test_ll: 13.039, val_ll: 12.832, test_ll: 12.842, lr: 2.00e-04
# epoch: 2090, time: 129s, train_ll: 13.083, ema_val_ll: 13.035, ema_test_ll: 13.042, val_ll: 12.860, test_ll: 12.862, lr: 2.00e-04
# epoch: 2100, time: 129s, train_ll: 13.085, ema_val_ll: 13.035, ema_test_ll: 13.042, val_ll: 12.809, test_ll: 12.819, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2110, time: 129s, train_ll: 13.087, ema_val_ll: 13.036, ema_test_ll: 13.042, val_ll: 12.883, test_ll: 12.886, lr: 2.00e-04
# epoch: 2120, time: 129s, train_ll: 13.089, ema_val_ll: 13.036, ema_test_ll: 13.042, val_ll: 12.854, test_ll: 12.861, lr: 2.00e-04
# epoch: 2130, time: 129s, train_ll: 13.089, ema_val_ll: 13.037, ema_test_ll: 13.044, val_ll: 12.860, test_ll: 12.868, lr: 2.00e-04
# epoch: 2140, time: 129s, train_ll: 13.091, ema_val_ll: 13.038, ema_test_ll: 13.045, val_ll: 12.833, test_ll: 12.838, lr: 2.00e-04
# epoch: 2150, time: 129s, train_ll: 13.093, ema_val_ll: 13.038, ema_test_ll: 13.044, val_ll: 12.854, test_ll: 12.854, lr: 2.00e-04
# epoch: 2160, time: 129s, train_ll: 13.093, ema_val_ll: 13.038, ema_test_ll: 13.044, val_ll: 12.819, test_ll: 12.826, lr: 2.00e-04
# epoch: 2170, time: 128s, train_ll: 13.095, ema_val_ll: 13.035, ema_test_ll: 13.042, val_ll: 12.844, test_ll: 12.856, lr: 2.00e-04
# epoch: 2180, time: 129s, train_ll: 13.097, ema_val_ll: 13.036, ema_test_ll: 13.043, val_ll: 12.850, test_ll: 12.852, lr: 2.00e-04
# epoch: 2190, time: 129s, train_ll: 13.098, ema_val_ll: 13.038, ema_test_ll: 13.044, val_ll: 12.847, test_ll: 12.851, lr: 2.00e-04
# epoch: 2200, time: 128s, train_ll: 13.101, ema_val_ll: 13.038, ema_test_ll: 13.044, val_ll: 12.836, test_ll: 12.845, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2210, time: 129s, train_ll: 13.102, ema_val_ll: 13.040, ema_test_ll: 13.046, val_ll: 12.845, test_ll: 12.855, lr: 2.00e-04
# epoch: 2220, time: 129s, train_ll: 13.103, ema_val_ll: 13.039, ema_test_ll: 13.045, val_ll: 12.814, test_ll: 12.818, lr: 2.00e-04
# epoch: 2230, time: 129s, train_ll: 13.105, ema_val_ll: 13.040, ema_test_ll: 13.046, val_ll: 12.848, test_ll: 12.852, lr: 2.00e-04
# epoch: 2240, time: 128s, train_ll: 13.106, ema_val_ll: 13.040, ema_test_ll: 13.046, val_ll: 12.834, test_ll: 12.834, lr: 2.00e-04
# epoch: 2250, time: 129s, train_ll: 13.108, ema_val_ll: 13.039, ema_test_ll: 13.045, val_ll: 12.881, test_ll: 12.887, lr: 2.00e-04
# epoch: 2260, time: 129s, train_ll: 13.110, ema_val_ll: 13.038, ema_test_ll: 13.045, val_ll: 12.855, test_ll: 12.855, lr: 2.00e-04
# epoch: 2270, time: 128s, train_ll: 13.111, ema_val_ll: 13.040, ema_test_ll: 13.046, val_ll: 12.827, test_ll: 12.827, lr: 2.00e-04
# epoch: 2280, time: 129s, train_ll: 13.113, ema_val_ll: 13.040, ema_test_ll: 13.046, val_ll: 12.866, test_ll: 12.874, lr: 2.00e-04
# epoch: 2290, time: 129s, train_ll: 13.114, ema_val_ll: 13.040, ema_test_ll: 13.047, val_ll: 12.867, test_ll: 12.874, lr: 2.00e-04
# epoch: 2300, time: 129s, train_ll: 13.116, ema_val_ll: 13.042, ema_test_ll: 13.049, val_ll: 12.874, test_ll: 12.886, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2310, time: 128s, train_ll: 13.116, ema_val_ll: 13.043, ema_test_ll: 13.049, val_ll: 12.801, test_ll: 12.808, lr: 2.00e-04
# epoch: 2320, time: 129s, train_ll: 13.118, ema_val_ll: 13.043, ema_test_ll: 13.049, val_ll: 12.825, test_ll: 12.832, lr: 2.00e-04
# epoch: 2330, time: 129s, train_ll: 13.119, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.847, test_ll: 12.854, lr: 2.00e-04
# epoch: 2340, time: 129s, train_ll: 13.120, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.728, test_ll: 12.736, lr: 2.00e-04
# epoch: 2350, time: 129s, train_ll: 13.122, ema_val_ll: 13.043, ema_test_ll: 13.049, val_ll: 12.868, test_ll: 12.879, lr: 2.00e-04
# epoch: 2360, time: 128s, train_ll: 13.123, ema_val_ll: 13.044, ema_test_ll: 13.049, val_ll: 12.832, test_ll: 12.835, lr: 2.00e-04
# epoch: 2370, time: 129s, train_ll: 13.125, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.855, test_ll: 12.861, lr: 2.00e-04
# epoch: 2380, time: 129s, train_ll: 13.126, ema_val_ll: 13.044, ema_test_ll: 13.049, val_ll: 12.873, test_ll: 12.880, lr: 2.00e-04
# epoch: 2390, time: 128s, train_ll: 13.128, ema_val_ll: 13.043, ema_test_ll: 13.049, val_ll: 12.874, test_ll: 12.878, lr: 2.00e-04
# epoch: 2400, time: 129s, train_ll: 13.129, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.867, test_ll: 12.868, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2410, time: 128s, train_ll: 13.130, ema_val_ll: 13.045, ema_test_ll: 13.050, val_ll: 12.862, test_ll: 12.871, lr: 2.00e-04
# epoch: 2420, time: 128s, train_ll: 13.132, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.852, test_ll: 12.862, lr: 2.00e-04
# epoch: 2430, time: 128s, train_ll: 13.132, ema_val_ll: 13.044, ema_test_ll: 13.050, val_ll: 12.871, test_ll: 12.878, lr: 2.00e-04
# epoch: 2440, time: 128s, train_ll: 13.134, ema_val_ll: 13.046, ema_test_ll: 13.051, val_ll: 12.859, test_ll: 12.861, lr: 2.00e-04
# epoch: 2450, time: 126s, train_ll: 13.135, ema_val_ll: 13.046, ema_test_ll: 13.051, val_ll: 12.816, test_ll: 12.818, lr: 2.00e-04
# epoch: 2460, time: 128s, train_ll: 13.136, ema_val_ll: 13.048, ema_test_ll: 13.053, val_ll: 12.833, test_ll: 12.833, lr: 2.00e-04
# epoch: 2470, time: 128s, train_ll: 13.138, ema_val_ll: 13.048, ema_test_ll: 13.053, val_ll: 12.877, test_ll: 12.881, lr: 2.00e-04
# epoch: 2480, time: 128s, train_ll: 13.139, ema_val_ll: 13.048, ema_test_ll: 13.054, val_ll: 12.832, test_ll: 12.835, lr: 2.00e-04
# epoch: 2490, time: 128s, train_ll: 13.141, ema_val_ll: 13.048, ema_test_ll: 13.053, val_ll: 12.867, test_ll: 12.874, lr: 2.00e-04
# epoch: 2500, time: 128s, train_ll: 13.141, ema_val_ll: 13.048, ema_test_ll: 13.053, val_ll: 12.883, test_ll: 12.887, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2510, time: 128s, train_ll: 13.143, ema_val_ll: 13.047, ema_test_ll: 13.052, val_ll: 12.840, test_ll: 12.845, lr: 2.00e-04
# epoch: 2520, time: 128s, train_ll: 13.145, ema_val_ll: 13.048, ema_test_ll: 13.053, val_ll: 12.850, test_ll: 12.853, lr: 2.00e-04
# epoch: 2530, time: 128s, train_ll: 13.146, ema_val_ll: 13.049, ema_test_ll: 13.054, val_ll: 12.870, test_ll: 12.872, lr: 2.00e-04
# epoch: 2540, time: 128s, train_ll: 13.147, ema_val_ll: 13.048, ema_test_ll: 13.054, val_ll: 12.859, test_ll: 12.866, lr: 2.00e-04
# epoch: 2550, time: 128s, train_ll: 13.147, ema_val_ll: 13.049, ema_test_ll: 13.055, val_ll: 12.763, test_ll: 12.768, lr: 2.00e-04
# epoch: 2560, time: 128s, train_ll: 13.149, ema_val_ll: 13.049, ema_test_ll: 13.055, val_ll: 12.873, test_ll: 12.880, lr: 2.00e-04
# epoch: 2570, time: 128s, train_ll: 13.150, ema_val_ll: 13.049, ema_test_ll: 13.055, val_ll: 12.816, test_ll: 12.818, lr: 2.00e-04
# epoch: 2580, time: 128s, train_ll: 13.152, ema_val_ll: 13.049, ema_test_ll: 13.054, val_ll: 12.811, test_ll: 12.821, lr: 2.00e-04
# epoch: 2590, time: 128s, train_ll: 13.152, ema_val_ll: 13.049, ema_test_ll: 13.054, val_ll: 12.864, test_ll: 12.869, lr: 2.00e-04
# epoch: 2600, time: 128s, train_ll: 13.154, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.879, test_ll: 12.885, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2610, time: 128s, train_ll: 13.155, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.896, test_ll: 12.899, lr: 2.00e-04
# epoch: 2620, time: 128s, train_ll: 13.156, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.866, test_ll: 12.876, lr: 2.00e-04
# epoch: 2630, time: 129s, train_ll: 13.158, ema_val_ll: 13.051, ema_test_ll: 13.056, val_ll: 12.783, test_ll: 12.791, lr: 2.00e-04
# epoch: 2650, time: 128s, train_ll: 13.160, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.863, test_ll: 12.867, lr: 2.00e-04
# epoch: 2660, time: 128s, train_ll: 13.161, ema_val_ll: 13.049, ema_test_ll: 13.054, val_ll: 12.812, test_ll: 12.818, lr: 2.00e-04
# epoch: 2670, time: 128s, train_ll: 13.163, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.879, test_ll: 12.888, lr: 2.00e-04
# epoch: 2680, time: 128s, train_ll: 13.163, ema_val_ll: 13.051, ema_test_ll: 13.056, val_ll: 12.864, test_ll: 12.867, lr: 2.00e-04
# epoch: 2690, time: 128s, train_ll: 13.165, ema_val_ll: 13.050, ema_test_ll: 13.055, val_ll: 12.881, test_ll: 12.887, lr: 2.00e-04
# epoch: 2700, time: 128s, train_ll: 13.166, ema_val_ll: 13.050, ema_test_ll: 13.056, val_ll: 12.884, test_ll: 12.890, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2710, time: 128s, train_ll: 13.167, ema_val_ll: 13.051, ema_test_ll: 13.057, val_ll: 12.860, test_ll: 12.861, lr: 2.00e-04
# epoch: 2720, time: 128s, train_ll: 13.167, ema_val_ll: 13.052, ema_test_ll: 13.057, val_ll: 12.896, test_ll: 12.900, lr: 2.00e-04
# epoch: 2730, time: 128s, train_ll: 13.169, ema_val_ll: 13.051, ema_test_ll: 13.056, val_ll: 12.862, test_ll: 12.871, lr: 2.00e-04
# epoch: 2740, time: 128s, train_ll: 13.170, ema_val_ll: 13.051, ema_test_ll: 13.057, val_ll: 12.851, test_ll: 12.854, lr: 2.00e-04
# epoch: 2750, time: 128s, train_ll: 13.170, ema_val_ll: 13.053, ema_test_ll: 13.058, val_ll: 12.886, test_ll: 12.896, lr: 2.00e-04
# epoch: 2760, time: 128s, train_ll: 13.172, ema_val_ll: 13.053, ema_test_ll: 13.058, val_ll: 12.848, test_ll: 12.851, lr: 2.00e-04
# epoch: 2770, time: 128s, train_ll: 13.174, ema_val_ll: 13.053, ema_test_ll: 13.058, val_ll: 12.804, test_ll: 12.808, lr: 2.00e-04
# epoch: 2780, time: 128s, train_ll: 13.174, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.899, test_ll: 12.905, lr: 2.00e-04
# epoch: 2790, time: 128s, train_ll: 13.175, ema_val_ll: 13.052, ema_test_ll: 13.058, val_ll: 12.893, test_ll: 12.899, lr: 2.00e-04
# epoch: 2800, time: 128s, train_ll: 13.177, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.886, test_ll: 12.894, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2810, time: 128s, train_ll: 13.177, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.859, test_ll: 12.870, lr: 2.00e-04
# epoch: 2820, time: 128s, train_ll: 13.178, ema_val_ll: 13.053, ema_test_ll: 13.058, val_ll: 12.851, test_ll: 12.858, lr: 2.00e-04
# epoch: 2830, time: 128s, train_ll: 13.180, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.866, test_ll: 12.875, lr: 2.00e-04
# epoch: 2840, time: 128s, train_ll: 13.181, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.895, test_ll: 12.900, lr: 2.00e-04
# epoch: 2850, time: 128s, train_ll: 13.182, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.849, test_ll: 12.856, lr: 2.00e-04
# epoch: 2860, time: 128s, train_ll: 13.183, ema_val_ll: 13.052, ema_test_ll: 13.058, val_ll: 12.865, test_ll: 12.868, lr: 2.00e-04
# epoch: 2870, time: 128s, train_ll: 13.184, ema_val_ll: 13.053, ema_test_ll: 13.059, val_ll: 12.883, test_ll: 12.887, lr: 2.00e-04
# epoch: 2880, time: 128s, train_ll: 13.186, ema_val_ll: 13.054, ema_test_ll: 13.060, val_ll: 12.879, test_ll: 12.884, lr: 2.00e-04
# epoch: 2890, time: 128s, train_ll: 13.186, ema_val_ll: 13.054, ema_test_ll: 13.059, val_ll: 12.867, test_ll: 12.870, lr: 2.00e-04
# epoch: 2900, time: 128s, train_ll: 13.187, ema_val_ll: 13.054, ema_test_ll: 13.060, val_ll: 12.811, test_ll: 12.822, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 2910, time: 128s, train_ll: 13.187, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.888, test_ll: 12.893, lr: 2.00e-04
# epoch: 2920, time: 128s, train_ll: 13.189, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.853, test_ll: 12.861, lr: 2.00e-04
# epoch: 2930, time: 128s, train_ll: 13.191, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.891, test_ll: 12.895, lr: 2.00e-04
# epoch: 2940, time: 129s, train_ll: 13.191, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.820, test_ll: 12.829, lr: 2.00e-04
# epoch: 2950, time: 128s, train_ll: 13.192, ema_val_ll: 13.056, ema_test_ll: 13.062, val_ll: 12.857, test_ll: 12.855, lr: 2.00e-04
# epoch: 2960, time: 128s, train_ll: 13.194, ema_val_ll: 13.056, ema_test_ll: 13.061, val_ll: 12.890, test_ll: 12.894, lr: 2.00e-04
# epoch: 2970, time: 128s, train_ll: 13.194, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.834, test_ll: 12.839, lr: 2.00e-04
# epoch: 2980, time: 128s, train_ll: 13.195, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.852, test_ll: 12.857, lr: 2.00e-04
# epoch: 2990, time: 128s, train_ll: 13.196, ema_val_ll: 13.055, ema_test_ll: 13.062, val_ll: 12.867, test_ll: 12.882, lr: 2.00e-04
# epoch: 3000, time: 127s, train_ll: 13.197, ema_val_ll: 13.056, ema_test_ll: 13.062, val_ll: 12.867, test_ll: 12.876, lr: 2.00e-04
# Namespace(add_residual_connections=False, batch_size=1024, bound_multiplier=1.0, dataset='gas', dont_normalize_inverse=False, dropout=0.1, gamma=1, gpu='6', hidden_dim=1024, learning_rate=0.0002, n_residual_blocks=2, nits_arch=[16, 16, 1], patience=10, permute_data=True, polyak_decay=0.99995, rotate=True, seed=1)
# epoch: 3010, time: 127s, train_ll: 13.197, ema_val_ll: 13.055, ema_test_ll: 13.061, val_ll: 12.898, test_ll: 12.904, lr: 2.00e-04
# epoch: 3020, time: 128s, train_ll: 13.199, ema_val_ll: 13.055, ema_test_ll: 13.062, val_ll: 12.820, test_ll: 12.831, lr: 2.00e-04
# epoch: 3030, time: 127s, train_ll: 13.200, ema_val_ll: 13.056, ema_test_ll: 13.062, val_ll: 12.823, test_ll: 12.827, lr: 2.00e-04
# epoch: 3040, time: 128s, train_ll: 13.200, ema_val_ll: 13.056, ema_test_ll: 13.063, val_ll: 12.886, test_ll: 12.893, lr: 2.00e-04
# Patience reached zero. max_val_ll stayed at 13.056 for 10 iterations.
# epoch: 3050, time: 128s, train_ll: 13.202, ema_val_ll: 13.056, ema_test_ll: 13.062, val_ll: 12.851, test_ll: 12.859, lr: 2.00e-04

# %%
P_hat = model.model.get_P()
v = torch.ones(d, device=device).reshape(1, -1) / np.sqrt(d)
print(v.norm())
print((v @ P_hat).norm())
P_hat.argmax(axis=0)
# Out:
# tensor(1.0000, device='cuda:6')
# tensor(1., device='cuda:6', grad_fn=<CopyBackwards>)
# tensor([2, 2, 0, 5, 6, 5, 0, 3], device='cuda:6')
